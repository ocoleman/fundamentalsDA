# %% [markdown]
# # Exploring Plots
#
# ***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use("ggplot")

# %%
plt.plot([1,2,3], "r-", label="Red Line")
plt.legend()

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3], "r-", label="Red Line")
ax.legend()

# %% [markdown]
# <br>
#
# #### Distplots
# ***

# %%
x = np.random.normal(1,2, 1000)
sns.distplot(x, kde=True)

# %% [markdown]
# <br>
#
# #### Bar chart

# %%
makes = ["Toyota", "Skoda", "VW", "BMW"]
cars = np.random.choice(makes, 10000)
cars
# Out:
# array(['VW', 'BMW', 'Skoda', ..., 'Skoda', 'VW', 'BMW'], dtype='<U6')

# %%
sns.countplot(x=list(cars))
