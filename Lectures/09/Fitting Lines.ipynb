# %% [markdown]
# # Fitting Lines
# ***

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

plt.rcParams["figure.figsize"] = (18,10)

# %%
x = np.linspace(0.0,10.0,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
len(x)
# Out:
# 100

# %%
y = 3.0 * x + 2.0

# %%
y
# Out:
# array([ 2.        ,  2.3030303 ,  2.60606061,  2.90909091,  3.21212121,
#         3.51515152,  3.81818182,  4.12121212,  4.42424242,  4.72727273,
#         5.03030303,  5.33333333,  5.63636364,  5.93939394,  6.24242424,
#         6.54545455,  6.84848485,  7.15151515,  7.45454545,  7.75757576,
#         8.06060606,  8.36363636,  8.66666667,  8.96969697,  9.27272727,
#         9.57575758,  9.87878788, 10.18181818, 10.48484848, 10.78787879,
#        11.09090909, 11.39393939, 11.6969697 , 12.        , 12.3030303 ,
#        12.60606061, 12.90909091, 13.21212121, 13.51515152, 13.81818182,
#        14.12121212, 14.42424242, 14.72727273, 15.03030303, 15.33333333,
#        15.63636364, 15.93939394, 16.24242424, 16.54545455, 16.84848485,
#        17.15151515, 17.45454545, 17.75757576, 18.06060606, 18.36363636,
#        18.66666667, 18.96969697, 19.27272727, 19.57575758, 19.87878788,
#        20.18181818, 20.48484848, 20.78787879, 21.09090909, 21.39393939,
#        21.6969697 , 22.        , 22.3030303 , 22.60606061, 22.90909091,
#        23.21212121, 23.51515152, 23.81818182, 24.12121212, 24.42424242,
#        24.72727273, 25.03030303, 25.33333333, 25.63636364, 25.93939394,
#        26.24242424, 26.54545455, 26.84848485, 27.15151515, 27.45454545,
#        27.75757576, 28.06060606, 28.36363636, 28.66666667, 28.96969697,
#        29.27272727, 29.57575758, 29.87878788, 30.18181818, 30.48484848,
#        30.78787879, 31.09090909, 31.39393939, 31.6969697 , 32.        ])

# %%
len(y)
# Out:
# 100

# %%
plt.plot(x, y,)

# %%
np.polyfit(x, y, 1)
# Out:
# array([3., 2.])

# %% [markdown]
# <br>
#
# #### Include some noise
# ***

# %%
y = 3.0 * x + 2.0 + np.random.normal(0.0, 30.0, len(x))

# %%
x
# Out:
# array([0.        , 0.02631579, 0.05263158, 0.07894737, 0.10526316,
#        0.13157895, 0.15789474, 0.18421053, 0.21052632, 0.23684211,
#        0.26315789, 0.28947368, 0.31578947, 0.34210526, 0.36842105,
#        0.39473684, 0.42105263, 0.44736842, 0.47368421, 0.5       ,
#        0.        , 0.01724138, 0.03448276, 0.05172414, 0.06896552,
#        0.0862069 , 0.10344828, 0.12068966, 0.13793103, 0.15517241,
#        0.17241379, 0.18965517, 0.20689655, 0.22413793, 0.24137931,
#        0.25862069, 0.27586207, 0.29310345, 0.31034483, 0.32758621,
#        0.34482759, 0.36206897, 0.37931034, 0.39655172, 0.4137931 ,
#        0.43103448, 0.44827586, 0.46551724, 0.48275862, 0.5       ])

# %%
y
# Out:
# array([ 2.09330478,  2.22094427,  2.44196424,  2.86469401,  3.2793334 ,
#         3.4608461 ,  3.77340211,  4.17575251,  4.36785036,  4.62572578,
#         5.002126  ,  5.1989275 ,  5.56303654,  6.11426173,  6.59515771,
#         6.39528143,  6.91685305,  7.22814143,  7.4732044 ,  7.77768812,
#         8.22891629,  8.33303028,  8.65589866,  8.94898165,  9.09261448,
#         9.4888645 ,  9.85979977, 10.14700367, 10.51515912, 10.83330717,
#        11.1464518 , 11.34130027, 11.63373532, 12.03403822, 12.11150316,
#        12.7530916 , 13.00329151, 13.35951806, 13.52636146, 13.7141421 ,
#        14.15071818, 14.50680519, 14.64913617, 14.91713331, 15.26551498,
#        15.71850222, 15.86968754, 16.08938139, 16.42429772, 17.03476228,
#        17.27243407, 17.34214421, 17.95634134, 18.1683384 , 18.48438642,
#        18.49029473, 19.21657218, 19.18156732, 19.66000034, 20.0010961 ,
#        20.32870859, 20.63534607, 20.81404756, 21.12304352, 21.50143675,
#        21.69711575, 22.02500468, 22.25450586, 22.49912856, 23.00813784,
#        23.34699515, 23.5036921 , 23.80168242, 24.2470456 , 24.372671  ,
#        24.62372967, 24.91090267, 25.1867369 , 25.56984451, 25.92643077,
#        26.36214416, 26.51111047, 26.68274747, 27.21200343, 27.5351502 ,
#        27.74202758, 28.05919907, 28.49761216, 28.72644481, 28.9798065 ,
#        29.30962097, 29.47685684, 29.87448347, 29.94291321, 30.49742122,
#        30.9274687 , 31.13588138, 31.31444439, 31.83893415, 31.9773397 ])

# %%
plt.plot(x, y, '.')

# %%
coeffs = np.polyfit(x, y, 1)
coeffs
# Out:
# array([2.99651016, 2.03345831])

# %%
plt.plot(x, y, '.', label="DATA")
plt.plot(x, coeffs[0] * x + coeffs[1], '-', label='Best fit')
plt.legend()

# %% [markdown]
# <br>
#
# #### More than one datatset on one plot
# ***

# %%
x1 =np.linspace(0.0, 0.5, 20)

# %%
y1 = 3.0 * x1 + 2.0 + np.random.normal(0.0, 1.0, len(x1))

# %%
x2 = np.linspace(0.0, 0.5, 30)

# %%
y2 = 6.0 * x2 + 5.0 + np.random.normal(0.0, 1.0, len(x2))

# %%
coeffs1 = np.polyfit(x1, y1, 1)
coeffs1
# Out:
# array([1.64093209, 2.40532915])

# %%
coeffs2 = np.polyfit(x2, y2, 1)
coeffs2
# Out:
# array([5.6005439 , 5.13996591])

# %%
plt.plot(x1, y1, '.', label="DATA Set 1")
plt.plot(x1, coeffs1[0] * x1 + coeffs1[1], '-', label='Best fit line 1')
plt.plot(x2, y2, '.', label="DATA Set 2")
plt.plot(x2, coeffs2[0] * x2 + coeffs2[1], '-', label='Best fit line 2')
plt.legend()

# %% [markdown]
# <br>
#
# #### Combine Datasets
# ***

# %%
x = np.concatenate([x1, x2])

# %%
y = np.concatenate([y1, y2])

# %%
coeffs = np.polyfit(x, y, 1)
coeffs
# Out:
# array([3.9848631 , 4.05407022])

# %%
plt.plot(x1, y1, '.', label="DATA Set 1")
plt.plot(x1, coeffs1[0] * x1 + coeffs1[1], '-', label='Best fit line 1')
plt.plot(x2, y2, '.', label="DATA Set 2")
plt.plot(x2, coeffs2[0] * x2 + coeffs2[1], '-', label='Best fit line 2')
# plt.plot(x, y, '.', label="DATA Set Combined")
plt.plot(x, coeffs[0] * x + coeffs[1], '-', label='Best fit combined')

plt.legend()
